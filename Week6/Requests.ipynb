# %%
import requests


url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'

r = requests.get(url)

print('URL:\n',r.url)
print('Status code:\n',r.status_code)
print('JSON:\n',r.json())
# Out:
# , 'description': 'A little bit about a linux kernel', 'fork': False, 'url': 'https://api.github.com/repos/0xAX/linux-insides', 'forks_url': 'https://api.github.com/repos/0xAX/linux-insides/forks', 'keys_url': 'https://api.github.com/repos/0xAX/linux-insides/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/0xAX/linux-insides/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/0xAX/linux-insides/teams', 'hooks_url': 'https://api.github.com/repos/0xAX/linux-insides/hooks', 'issue_events_url': 'https://api.github.com/repos/0xAX/linux-insides/issues/events{/number}', 'events_url': 'https://api.github.com/repos/0xAX/linux-insides/events', 'assignees_url': 'https://api.github.com/repos/0xAX/linux-insides/assignees{/user}', 'branches_url': 'https://api.github.com/repos/0xAX/linux-insides/branches{/branch}', 'tags_url': 'https://api.github.com/repos/0xAX/linux-insides/tags', 'blobs_url': 'https://api.github.com/repos/0xAX/linux-insides/git/blobs{/sha}',
# ...
